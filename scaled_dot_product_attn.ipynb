# %%
import torch

# %%
x = torch.randn(1, 3, 4)
x
# Out:
# tensor([[[-0.0658,  1.9883,  0.5703,  0.3035],
#          [ 1.2202, -1.4762, -1.3049,  0.5545],
#          [-1.0375, -0.6624, -0.7064, -1.3282]]])

# %%
x.size(), x.shape
# Out:
# (torch.Size([1, 3, 4]), torch.Size([1, 3, 4]))

# %%
x_norm = x - torch.max(x, dim=-1, keepdim=True)[0]
print(x_norm.shape)
x_norm
# Out:
# torch.Size([1, 3, 4])
# tensor([[[-2.0542,  0.0000, -1.4180, -1.6849],
#          [ 0.0000, -2.6965, -2.5252, -0.6657],
#          [-0.3751,  0.0000, -0.0440, -0.6658]]])
